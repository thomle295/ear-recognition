# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/Research/FU_AI_LAB/Ear_recognize/"
# Out:
# /content/drive/My Drive/Research/FU_AI_LAB/Ear_recognize

# %%
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from tqdm import tqdm_notebook as tqdm
import time
import pickle
tqdm().pandas()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# 0it [00:00, ?it/s]

# %%
CATE_DATASET_PATH = "./Dataset/EarVN1.0dataset/Images/"

# %%
categories = os.listdir(CATE_DATASET_PATH)
print(categories)
# Out:
# ['029.Ho_Trung_D', '081.Thanh_D', '024.Gin_Tuan_K', '122.La_Thanh_H', '002.LeDuong_BL', '155.Truong_Quynh_A', '109.Go_Joon_H', '075.Rym', '162.Vu_Cat_T', '114.Kieu_Tr', '052.Luong_Bang_Q', '135.Minh_T', '026.Hac_Hoa_K', '014.Dan_Ng', '083.ThanhTr', '020.Duong_D', '137.My_T', '095.Tung_Dg', '132.Mid_Ng', '007.Chau_KP', '149.Thuy_H', '099.Amber', '104.Chau_B', '110.H_Hen_N', '008.Chi_D', '143.Pham_Thanh_H', '050.Long_Nh', '009.Chi_Th', '028.Ho_Quang_H', '153.Trang_Ph', '051.Lou_Ho', '017.Dao_Ba_L', '043.L_HA', '121.Kim_Yoo_J', '021.Dustin_Phuc_Ng', '103.Cha_Mi', '087.Tran Th', '064.Noo_Phuoc_Th', '036.Jun_Ph', '035.Isaac', '065.Ong_Cao_Th', '154.Trieu_Le_D', '116.Kim_Ji_W', '030.Hoai_L', '078.ST', '161.Vo_Hoang_Y', '088.Trinh_Thang_B', '152.Trang_K', '086.Tran Dinh Q', '133.Minh_H', '038.Kenvin_Kh', '150.Toc_T', '076.Sky_ST', '130.Mai_Ng', '163.Xa_Thi_M', '040.Khuong_Ng', '013.Dam_Vinh_H', '010.Chu_B', '047.Lam_Vinh_H', '037.Justatee', '012.Dai_Nhan', '059.Ngo_Kien_H', '140.Nguyen_Thi_Tram', '134.Minh_Tr', '067.Pham_Hong_Ph', '061.Nguyen_Phi_Hu', '164.Yen_Nhi_H', '042.Kim_L', '113.Khong_Tu_Qu', '046.Lam_Tr', '019.Don_Ng', '001.ALI_HD', '041.Kieu_Minh_T', '117.Kim_Ng', '049.Lee_Min_H', '044.Lam_Canh_T', '033.Huynh_L', '018.De_C', '054.Luong_The_Th', '107.Duong_M', '090.Truc_nh', '101.Cao_Ng', '111.Hang_Ng', '144.Quynh_Anh_Sh', '102.Cao_Thien_Tr', '160.Viet_H', '092.TruonGNam_th', '096.Ung_DaiV', '045.Lam_Hu', '031.Hoang_Rap', '091.TrungQua', '070.Phan_M_Quy', '005.Bui_AT', '053.Luong_Manh_H', '123.Lan_Kh', '106.Do_My_L', '032.Huy_Tr', '069.Phan_A', '097.UngHoaP', '084.TIM', '151.Tran_Kieu_A', '034.Huynh_Ph', '115.Kim_Hye_S', '158.Van_h', '156.Tu_H', '136.Miu_L', '129.Mai_H', '105.Dich_Le_Nhiet', '085.Toulive', '027.Hamtet_Tr', '138.Ngo_Thanh_V', '003.BD_Tran', '074.Quy_B', '011.Cong_To', '125.Le_Ph', '072.Quang_Ha', '006.Chau_GK', '120.Kim_So_H', '079.Ta_Quang_T', '080.Thai_V', '146.Tam_T', '148.Thu_Tr', '077.Soobin_HS', '025.Ha_Anh_T', '118.Kim_Nh', '057.Nam_Cuog', '068.Pham_Tr', '058.Ngo_Diec_P', '093.TruongThe_V', '004.Binz', '060.Nguyen_Khang', '062.Nguyen_Tran_Trung_Qu', '142.Pham_My_L', '023.Erik', '126.Le_Thanh_Th', '128.Ly_Nha_K', '112.IU', '098.V_rau', '108.Gil_L', '141.Pham_H', '071.Quang_B', '048.Lee_Jong_S', '139.Ngoc_Qu', '157.Uyen_L', '056.Mai_Tai_Ph', '063.Nhan_Phuc_V', '124.Le_Cat_Trong_L', '039.KhacVi', '082.Thanh_Lo', '100.Angela_Ba', '073.Quang_Tr', '127.Luu-Diec_P', '131.Mau_Thanh_Th', '147.Thu_M', '055.Ly_Dich_P', '119.Kim_Ph', '159.Van_Mai_H', '145.Suzy', '066.OnlyC', '089.Trong_Hie', '022.Duy_Kh', '094.Tuan_Hu', '015.Dan_Trg', '016.Dang_L']

# %%
IMG_HEIGHT = 257
IMG_WIDTH = 161
BATCH_SIZE = 32

training_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    CATE_DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size =(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    CATE_DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size =(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE
)
# Out:
# Found 28422 files belonging to 164 classes.
# Using 22738 files for training.
# Found 28422 files belonging to 164 classes.
# Using 5684 files for validation.

# %%
# for image_batch, labels_batch in training_dataset:
#     print(image_batch.shape)
#     print(labels_batch.shape)

#     break

# %%
param_grid={
    'C':[0.1,1,100],
    'gamma':[0.0001,0.001],
    'kernel':['rbf','poly']
    }

# %%
svc = svm.SVC(probability=True)

# %%
len(training_dataset)
# Out:
# 711

# %%
# %%capture

batch_index = 0
with tqdm(total=len(training_dataset), desc ="train") as pbar:
    for image_batch, labels_batch in training_dataset:
        print(image_batch.shape)
        print(labels_batch.shape)
        batch_index = batch_index + 1
        print("batch_index: ", batch_index)

        flat_data_arr = []
        target_arr = []

        with tqdm(total=BATCH_SIZE, desc ="convert_tf_to_numpy") as psubbar:
            for i in range(BATCH_SIZE):
                flat_data = np.array(image_batch).flatten()
                target = np.array(labels_batch)

                flat_data_arr.append(flat_data)
                target_arr.append(target)
                psubbar.update(1)


        df = pd.DataFrame(flat_data_arr)
        df['Target'] = target_arr

        x = df.iloc[:,:-1]
        y = df.iloc[:,-1]

        if batch_index == 1:
            model = GridSearchCV(svc,param_grid)

        model.fit(x,y)
        del df
        pbar.update(1)

pickle.dump(model,open('img_model.p','wb'))
print("Pickle is dumped successfully")

# %%
flat_data_arr=[] #input array
target_arr=[] #output array

for i in categories:
    print(f'loading... category : {i}')
    path=os.path.join(CATE_DATASET_PATH,i)
    for img in os.listdir(path):
        img_array=imread(os.path.join(path,img))
        img_resized=resize(img_array,(257,161,3))
        flat_data_arr.append(img_resized.flatten())
        target_arr.append(categories.index(i))
        del img_array
        del img_resized
    print(f'loaded category:{i} successfully')
# Out:
# loading... category : 029.Ho_Trung_D
# loaded category:029.Ho_Trung_D successfully
# loading... category : 081.Thanh_D
# loaded category:081.Thanh_D successfully
# loading... category : 024.Gin_Tuan_K
# loaded category:024.Gin_Tuan_K successfully
# loading... category : 122.La_Thanh_H
# loaded category:122.La_Thanh_H successfully
# loading... category : 002.LeDuong_BL
# loaded category:002.LeDuong_BL successfully
# loading... category : 155.Truong_Quynh_A
# loaded category:155.Truong_Quynh_A successfully
# loading... category : 109.Go_Joon_H
# loaded category:109.Go_Joon_H successfully
# loading... category : 075.Rym
# loaded category:075.Rym successfully
# loading... category : 162.Vu_Cat_T
# loaded category:162.Vu_Cat_T successfully
# loading... category : 114.Kieu_Tr
# loaded category:114.Kieu_Tr successfully
# loading... category : 052.Luong_Bang_Q
# loaded category:052.Luong_Bang_Q successfully
# loading... category : 135.Minh_T
# loaded category:135.Minh_T successfully
# loading... category : 026.Hac_Hoa_K
# loaded category:026.Hac_Hoa_K successfully
# loading... category : 014.Dan_Ng
# loaded category:014.Dan_Ng successfully
# loading... category : 083.ThanhTr
# loaded category:083.ThanhTr successfully
# loading... category : 020.Duong_D
# loaded category:020.Duong_D successfully
# loading... category : 137.My_T
# loaded category:137.My_T successfully
# loading... category : 095.Tung_Dg
# loaded category:095.Tung_Dg successfully
# loading... category : 132.Mid_Ng
# loaded category:132.Mid_Ng successfully
# loading... category : 007.Chau_KP
# loaded category:007.Chau_KP successfully
# loading... category : 149.Thuy_H
# loaded category:149.Thuy_H successfully
# loading... category : 099.Amber
# loaded category:099.Amber successfully
# loading... category : 104.Chau_B
# loaded category:104.Chau_B successfully
# loading... category : 110.H_Hen_N
# loaded category:110.H_Hen_N successfully
# loading... category : 008.Chi_D
# loaded category:008.Chi_D successfully
# loading... category : 143.Pham_Thanh_H
# loaded category:143.Pham_Thanh_H successfully
# loading... category : 050.Long_Nh
# loaded category:050.Long_Nh successfully
# loading... category : 009.Chi_Th
# loaded category:009.Chi_Th successfully
# loading... category : 028.Ho_Quang_H
# loaded category:028.Ho_Quang_H successfully
# loading... category : 153.Trang_Ph
# loaded category:153.Trang_Ph successfully
# loading... category : 051.Lou_Ho
# loaded category:051.Lou_Ho successfully
# loading... category : 017.Dao_Ba_L
# loaded category:017.Dao_Ba_L successfully
# loading... category : 043.L_HA
# loaded category:043.L_HA successfully
# loading... category : 121.Kim_Yoo_J
# loaded category:121.Kim_Yoo_J successfully
# loading... category : 021.Dustin_Phuc_Ng
# loaded category:021.Dustin_Phuc_Ng successfully
# loading... category : 103.Cha_Mi
# loaded category:103.Cha_Mi successfully
# loading... category : 087.Tran Th
# loaded category:087.Tran Th successfully
# loading... category : 064.Noo_Phuoc_Th
# loaded category:064.Noo_Phuoc_Th successfully
# loading... category : 036.Jun_Ph
# loaded category:036.Jun_Ph successfully
# loading... category : 035.Isaac
# loaded category:035.Isaac successfully
# loading... category : 065.Ong_Cao_Th
# loaded category:065.Ong_Cao_Th successfully
# loading... category : 154.Trieu_Le_D
# loaded category:154.Trieu_Le_D successfully
# loading... category : 116.Kim_Ji_W
# loaded category:116.Kim_Ji_W successfully
# loading... category : 030.Hoai_L
# loaded category:030.Hoai_L successfully
# loading... category : 078.ST
# loaded category:078.ST successfully
# loading... category : 161.Vo_Hoang_Y
# loaded category:161.Vo_Hoang_Y successfully
# loading... category : 088.Trinh_Thang_B
# loaded category:088.Trinh_Thang_B successfully
# loading... category : 152.Trang_K
# loaded category:152.Trang_K successfully
# loading... category : 086.Tran Dinh Q
# loaded category:086.Tran Dinh Q successfully
# loading... category : 133.Minh_H
# loaded category:133.Minh_H successfully
# loading... category : 038.Kenvin_Kh
# loaded category:038.Kenvin_Kh successfully
# loading... category : 150.Toc_T
# loaded category:150.Toc_T successfully
# loading... category : 076.Sky_ST
# loaded category:076.Sky_ST successfully
# loading... category : 130.Mai_Ng
# loaded category:130.Mai_Ng successfully
# loading... category : 163.Xa_Thi_M
# loaded category:163.Xa_Thi_M successfully
# loading... category : 040.Khuong_Ng
# loaded category:040.Khuong_Ng successfully
# loading... category : 013.Dam_Vinh_H
# loaded category:013.Dam_Vinh_H successfully
# loading... category : 010.Chu_B
# loaded category:010.Chu_B successfully
# loading... category : 047.Lam_Vinh_H
# loaded category:047.Lam_Vinh_H successfully
# loading... category : 037.Justatee
# loaded category:037.Justatee successfully
# loading... category : 012.Dai_Nhan
# loaded category:012.Dai_Nhan successfully
# loading... category : 059.Ngo_Kien_H
# loaded category:059.Ngo_Kien_H successfully
# loading... category : 140.Nguyen_Thi_Tram
# loaded category:140.Nguyen_Thi_Tram successfully
# loading... category : 134.Minh_Tr
# loaded category:134.Minh_Tr successfully
# loading... category : 067.Pham_Hong_Ph
# loaded category:067.Pham_Hong_Ph successfully
# loading... category : 061.Nguyen_Phi_Hu
# loaded category:061.Nguyen_Phi_Hu successfully
# loading... category : 164.Yen_Nhi_H
# loaded category:164.Yen_Nhi_H successfully
# loading... category : 042.Kim_L
# loaded category:042.Kim_L successfully
# loading... category : 113.Khong_Tu_Qu
# loaded category:113.Khong_Tu_Qu successfully
# loading... category : 046.Lam_Tr
# loaded category:046.Lam_Tr successfully
# loading... category : 019.Don_Ng
# loaded category:019.Don_Ng successfully
# loading... category : 001.ALI_HD
# loaded category:001.ALI_HD successfully
# loading... category : 041.Kieu_Minh_T
# loaded category:041.Kieu_Minh_T successfully
# loading... category : 117.Kim_Ng
# loaded category:117.Kim_Ng successfully
# loading... category : 049.Lee_Min_H
# loaded category:049.Lee_Min_H successfully
# loading... category : 044.Lam_Canh_T
# loaded category:044.Lam_Canh_T successfully
# loading... category : 033.Huynh_L
# loaded category:033.Huynh_L successfully
# loading... category : 018.De_C
# loaded category:018.De_C successfully
# loading... category : 054.Luong_The_Th
# loaded category:054.Luong_The_Th successfully
# loading... category : 107.Duong_M
# loaded category:107.Duong_M successfully
# loading... category : 090.Truc_nh
# loaded category:090.Truc_nh successfully
# loading... category : 101.Cao_Ng
# loaded category:101.Cao_Ng successfully
# loading... category : 111.Hang_Ng
# loaded category:111.Hang_Ng successfully
# loading... category : 144.Quynh_Anh_Sh
# loaded category:144.Quynh_Anh_Sh successfully
# loading... category : 102.Cao_Thien_Tr
# loaded category:102.Cao_Thien_Tr successfully
# loading... category : 160.Viet_H
# loaded category:160.Viet_H successfully
# loading... category : 092.TruonGNam_th
# loaded category:092.TruonGNam_th successfully
# loading... category : 096.Ung_DaiV
# loaded category:096.Ung_DaiV successfully
# loading... category : 045.Lam_Hu
# loaded category:045.Lam_Hu successfully
# loading... category : 031.Hoang_Rap
# loaded category:031.Hoang_Rap successfully
# loading... category : 091.TrungQua
# loaded category:091.TrungQua successfully
# loading... category : 070.Phan_M_Quy
# loaded category:070.Phan_M_Quy successfully
# loading... category : 005.Bui_AT
# loaded category:005.Bui_AT successfully
# loading... category : 053.Luong_Manh_H
# loaded category:053.Luong_Manh_H successfully
# loading... category : 123.Lan_Kh
# loaded category:123.Lan_Kh successfully
# loading... category : 106.Do_My_L
# loaded category:106.Do_My_L successfully
# loading... category : 032.Huy_Tr
# loaded category:032.Huy_Tr successfully
# loading... category : 069.Phan_A
# loaded category:069.Phan_A successfully
# loading... category : 097.UngHoaP
# loaded category:097.UngHoaP successfully
# loading... category : 084.TIM
# loaded category:084.TIM successfully
# loading... category : 151.Tran_Kieu_A
# loaded category:151.Tran_Kieu_A successfully
# loading... category : 034.Huynh_Ph
# loaded category:034.Huynh_Ph successfully
# loading... category : 115.Kim_Hye_S
# loaded category:115.Kim_Hye_S successfully
# loading... category : 158.Van_h
# loaded category:158.Van_h successfully
# loading... category : 156.Tu_H
# loaded category:156.Tu_H successfully
# loading... category : 136.Miu_L
# loaded category:136.Miu_L successfully
# loading... category : 129.Mai_H
# loaded category:129.Mai_H successfully
# loading... category : 105.Dich_Le_Nhiet
# loaded category:105.Dich_Le_Nhiet successfully
# loading... category : 085.Toulive
# loaded category:085.Toulive successfully
# loading... category : 027.Hamtet_Tr
# loaded category:027.Hamtet_Tr successfully
# loading... category : 138.Ngo_Thanh_V
# loaded category:138.Ngo_Thanh_V successfully
# loading... category : 003.BD_Tran
# loaded category:003.BD_Tran successfully
# loading... category : 074.Quy_B
# loaded category:074.Quy_B successfully
# loading... category : 011.Cong_To
# loaded category:011.Cong_To successfully
# loading... category : 125.Le_Ph
# loaded category:125.Le_Ph successfully
# loading... category : 072.Quang_Ha
# loaded category:072.Quang_Ha successfully
# loading... category : 006.Chau_GK
# loaded category:006.Chau_GK successfully
# loading... category : 120.Kim_So_H
# loaded category:120.Kim_So_H successfully
# loading... category : 079.Ta_Quang_T
# loaded category:079.Ta_Quang_T successfully
# loading... category : 080.Thai_V
# loaded category:080.Thai_V successfully
# loading... category : 146.Tam_T
# loaded category:146.Tam_T successfully
# loading... category : 148.Thu_Tr
# loaded category:148.Thu_Tr successfully
# loading... category : 077.Soobin_HS
# loaded category:077.Soobin_HS successfully
# loading... category : 025.Ha_Anh_T
# loaded category:025.Ha_Anh_T successfully
# loading... category : 118.Kim_Nh
# loaded category:118.Kim_Nh successfully
# loading... category : 057.Nam_Cuog
# loaded category:057.Nam_Cuog successfully
# loading... category : 068.Pham_Tr
# loaded category:068.Pham_Tr successfully
# loading... category : 058.Ngo_Diec_P
# loaded category:058.Ngo_Diec_P successfully
# loading... category : 093.TruongThe_V
# loaded category:093.TruongThe_V successfully
# loading... category : 004.Binz
# loaded category:004.Binz successfully
# loading... category : 060.Nguyen_Khang
# loaded category:060.Nguyen_Khang successfully
# loading... category : 062.Nguyen_Tran_Trung_Qu
# loaded category:062.Nguyen_Tran_Trung_Qu successfully
# loading... category : 142.Pham_My_L
# loaded category:142.Pham_My_L successfully
# loading... category : 023.Erik
# loaded category:023.Erik successfully
# loading... category : 126.Le_Thanh_Th
# loaded category:126.Le_Thanh_Th successfully
# loading... category : 128.Ly_Nha_K
# loaded category:128.Ly_Nha_K successfully
# loading... category : 112.IU
# loaded category:112.IU successfully
# loading... category : 098.V_rau
# loaded category:098.V_rau successfully
# loading... category : 108.Gil_L
# loaded category:108.Gil_L successfully
# loading... category : 141.Pham_H
# loaded category:141.Pham_H successfully
# loading... category : 071.Quang_B
# loaded category:071.Quang_B successfully
# loading... category : 048.Lee_Jong_S
# loaded category:048.Lee_Jong_S successfully
# loading... category : 139.Ngoc_Qu
# loaded category:139.Ngoc_Qu successfully
# loading... category : 157.Uyen_L
# loaded category:157.Uyen_L successfully
# loading... category : 056.Mai_Tai_Ph
# loaded category:056.Mai_Tai_Ph successfully
# loading... category : 063.Nhan_Phuc_V
